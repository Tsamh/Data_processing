# %% [markdown]
# # importation des bibliotheques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # chargement du dataset

# %%
dataset = pd.read_csv("diabetes_dataset (1).csv")
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset1 = pd.read_csv("dataset_stroke_nouv.csv")
dataset1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
dataset1.shape
# Out:
# (5110, 12)

# %%
dataset1.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        4856.000000  4390.000000  5110.000000
# mean          106.274014    28.930342     0.048728
# std            45.370994     7.801910     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.407500    23.600000     0.000000
# 50%            91.990000    28.100000     0.000000
# ...

# %%
dataset1.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
dataset1.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level    254
# bmi                  720
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
dataset1['bmi'].isna().sum()
# Out:
# np.int64(720)

# %%
dataset1['avg_glucose_level'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Name: avg_glucose_level, Length: 5110, dtype: bool

# %%
dataset1['bmi'] = dataset1['bmi'].fillna(dataset1['bmi'].mean())
print(dataset1['bmi'])
# Out:
# 0       36.600000
# 1       28.930342
# 2       32.500000
# 3       34.400000
# 4       24.000000
#           ...
# 5105    28.930342
# 5106    40.000000
# 5107    28.930342
# 5108    25.600000
# 5109    26.200000
# Name: bmi, Length: 5110, dtype: float64
